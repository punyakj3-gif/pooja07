# %% [markdown]
# <a href="https://colab.research.google.com/github/punyakj3-gif/pooja07/blob/main/ex3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'First':['Arujan','Rohan','Riya','Yash','siddini'],
    'Lastname':['Singli','Agarwal','Shah','Batia','Khan',],
    'Type':['Full_time employee','Intern','Full_time employee','part time employee','Full_time employee'],
    'Department':['Administration','technical','Administration','Technical','Technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,1000,200000,0]
}
df=pd.DataFrame(data)
print(df)
# Out:
#      First Lastname                Type      Department  yoe  salary
# 0   Arujan   Singli  Full_time employee  Administration    2   20000
# 1    Rohan  Agarwal              Intern       technical    3    5000
# 2     Riya     Shah  Full_time employee  Administration    5    1000
# 3     Yash    Batia  part time employee       Technical    7  200000
# 4  siddini     Khan  Full_time employee       Technical    6       0
